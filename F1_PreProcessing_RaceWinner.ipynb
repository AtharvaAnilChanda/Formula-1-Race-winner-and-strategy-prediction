# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Atharv\Downloads\CompleteRace.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Sl. No Session  RaceNo  DriverNumber                 LapTime  LapNumber  \
# 0       1.0     FP1       1             1  0 days 00:01:34.742000          7
# 1       2.0     FP1       1            55  0 days 00:01:34.611000         14
# 2       3.0     FP1       1            47  0 days 00:01:36.536000         10
# 3       4.0     FP1       1            44  0 days 00:01:34.943000         13
# 4       5.0     FP1       1            31  0 days 00:01:35.151000          9
# ..      ...     ...     ...           ...                     ...        ...
# 366     NaN       Q       5            47  0 days 00:01:30.423000         13
# 367     NaN       Q       5            20  0 days 00:01:30.975000          9
# 368     NaN       Q       5            24  0 days 00:01:31.020000          4
# 369     NaN       Q       5            23  0 days 00:01:31.266000          7
# 370     NaN       Q       5             6  0 days 00:01:31.325000          9
#
# ...

# %%
df=df.sort_values(["RaceNo","Session","LapTime"])

# %%
'''i=1
if df['Session']=='FP1' and df['RaceNo']==1:
    df['GridPosition'] = i
    i+=1'''
i = 0
L = []
prev = ""
df['GridNo'] = ''
for index, row in df.iterrows():
    #print(prev, row['Session'])
    if(prev != row['Session']):
        #print(prev, row['Session'])
        i = 0
    i = i + 1
    L.append(i)
    prev = row['Session']
df['GridNo'] = L

# %%
df.head
# Out:
# <bound method NDFrame.head of      Sl. No Session  RaceNo  DriverNumber                 LapTime  LapNumber  \
# 14     15.0     FP1       1            10  0 days 00:01:34.193000         13
# 11     12.0     FP1       1            16  0 days 00:01:34.557000         14
# 1       2.0     FP1       1            55  0 days 00:01:34.611000         14
# 18     19.0     FP1       1            63  0 days 00:01:34.629000         12
# 0       1.0     FP1       1             1  0 days 00:01:34.742000          7
# ..      ...     ...     ...           ...                     ...        ...
# 361     NaN       Q       5            18  0 days 00:01:30.676000         20
# 367     NaN       Q       5            20  0 days 00:01:30.975000          9
# 368     NaN       Q       5            24  0 days 00:01:31.020000          4
# 369     NaN       Q       5            23  0 days 00:01:31.266000          7
# 370     NaN       Q       5             6  0 days 00:01:31.325000          9
#
# ...

# %%
df.to_csv(r'C:\Users\Atharv\Documents\f1_data_cache\WithGrid55.csv')
